# %% [markdown]
# # Pandas 실습 with stock data

# %% [markdown]
# - pandas (Python Data Analysis Library) : 데이터 입출력, 가공, 분석 등을 위한 대표적인 파이썬 라이브러리
# - S&P 500 데이터를 활용하여 데이터 가공 실습 진행
# - source: https://www.kaggle.com/datasets/andrewmvd/sp-500-stocks?select=sp500_companies.csv

# %%
import pandas as pd

# %% [markdown]
# - 실습 1
#     1. 데이터 타입(data type)
#     2. 읽고 쓰기(read/write)
#     3. 출력(print)
#     4. 인덱싱(indexing) & 슬라이싱(slicing)
#     5. 정렬(sorting)
#     6. 행/열 이름 변경(rename)
#     7. 복사(copy)
#
#
# - 실습 2
#     1. 함수 적용(apply operations)
#         - map
#         - apply
#         - applymap
#         - transform
#         - groupby
#         - rolling
#         - expanding
#
#     2. 데이터 변환
#         - transpose
#         - pivot/pivot_table
#         - stack
#         - unstack
#     3. 데이터 합치기
#         - merge
#         - join
#         - concat
#
# - 실습 3
#     1. 데이터 형식
#     2. 날짜 데이터 가공
#     3. 문자열 데이터 가공
#     4. 통계 함수들
#     5. 여러 유용한 함수들 (shift, diff, pct_change, cumsum, cumprod)
#     6. 결측치 처리
#     7. 그래프 그리기

# %% [markdown]
# # Pandas 실습 1

# %%
pd.DataFrame
pd.Series
pd.Index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1ddda7f2721f> in <module>
# ----> 1 pd.DataFrame
#       2 pd.Series
#       3 pd.Index
#
# NameError: name 'pd' is not defined

# %% [markdown]
# ## 데이터 타입(data type)
# - DataFrame : 테이블 전체
# - Index : 인덱스(행 또는 열)
# - Series : 1개 행 또는 열 (각 Series는 dtype을 가짐. 동일한 구조의 Series를 합치면 DataFrame)

# %% [markdown]
# ![dataframe?](./img/dataframe.png)

# %% [markdown]
# ## 읽고 쓰기(read/write)

# %% [markdown]
# - pd.read_csv : csv 데이터 로드
# - pd.read_* : 특정 타입으로 된 데이터 로드
# - pd.to_* : 특정 타입으로 데이터 저장/출력

# %%
# snp_comps : S&P 500 composite stocks
# snp_price : S&P 500 historical +ㅣ
# snp_stocks : historical price (OHLCV) for stocks

snp_comps = pd.read_csv('./data/sp500_companies.csv')
snp_price = pd.read_csv('./data/sp500_index.csv')
snp_stocks = pd.read_csv('./data/sp500_stocks.csv')

# %%
snp_stocks
# Out:
#                Date Symbol   Adj Close       Close        High         Low  \
# 0        2010-01-04    MMM   59.318886   83.019997   83.449997   82.669998
# 1        2010-01-05    MMM   58.947342   82.500000   83.230003   81.699997
# 2        2010-01-06    MMM   59.783295   83.669998   84.599998   83.510002
# 3        2010-01-07    MMM   59.826176   83.730003   83.760002   82.120003
# 4        2010-01-08    MMM   60.247749   84.320000   84.320000   83.300003
# ...             ...    ...         ...         ...         ...         ...
# 1625691  2022-10-27    ZTS  151.139999  151.139999  152.960007  149.520004
# 1625692  2022-10-28    ZTS  153.279999  153.279999  153.880005  150.520004
# 1625693  2022-10-31    ZTS  150.779999  150.779999  153.339996  149.839996
# 1625694  2022-11-01    ZTS  152.720001  152.720001  154.910004  150.380005
# 1625695  2022-11-02    ZTS  147.360001  147.360001  153.210007  147.220001
#
#                Open     Volume
# 0         83.089996  3043700.0
# 1         82.800003  2847000.0
# 2         83.879997  5268500.0
# 3         83.320000  4470100.0
# 4         83.690002  3405800.0
# ...             ...        ...
# 1625691  152.610001  2343700.0
# 1625692  152.100006  1615500.0
# 1625693  152.110001  1899000.0
# 1625694  151.399994  2286200.0
# 1625695  151.399994  2638272.0
#
# [1625696 rows x 8 columns]

# %% [markdown]
# ## 출력(print)

# %%
# 최대 출력 컬럼 수
print(pd.options.display.max_columns)
# 최대 출력 행 수
print(pd.options.display.max_rows)
# Out:
# 20
# 60

# %%
pd.options.display.max_rows = 60

# %%
snp_comps.index
# Out:
# RangeIndex(start=0, stop=495, step=1)

# %%
snp_comps.head(10)
# Out:
#   Exchange Symbol                        Shortname  \
# 0      NMS   AAPL                       Apple Inc.
# 1      NMS   MSFT            Microsoft Corporation
# 2      NMS  GOOGL                    Alphabet Inc.
# 3      NMS   GOOG                    Alphabet Inc.
# 4      NMS   AMZN                 Amazon.com, Inc.
# 5      NYQ  BRK-B      Berkshire Hathaway Inc. New
# 6      NYQ    UNH  UnitedHealth Group Incorporated
# 7      NYQ    XOM          Exxon Mobil Corporation
# 8      NYQ    JNJ                Johnson & Johnson
# 9      NYQ    WMT                     Walmart Inc.
#
#                           Longname                  Sector  \
# 0                       Apple Inc.              Technology
# 1            Microsoft Corporation              Technology
# 2                    Alphabet Inc.  Communication Services
# 3                    Alphabet Inc.  Communication Services
# 4                 Amazon.com, Inc.       Consumer Cyclical
# 5          Berkshire Hathaway Inc.      Financial Services
# 6  UnitedHealth Group Incorporated              Healthcare
# 7          Exxon Mobil Corporation                  Energy
# 8                Johnson & Johnson              Healthcare
# 9                     Walmart Inc.      Consumer Defensive
#
#                          Industry  Currentprice      Marketcap        Ebitda  \
# 0            Consumer Electronics        145.03  2307151626240  1.305410e+11
# 1         Software—Infrastructure        220.10  1652506361856  9.798300e+10
# 2  Internet Content & Information         86.97  1126496337920  9.373300e+10
# 3  Internet Content & Information         87.07  1125998002176  9.373300e+10
# 4                 Internet Retail         92.12   939780669440  5.154900e+10
# 5           Insurance—Diversified        289.46   638525571072  2.651600e+10
# 6                Healthcare Plans        543.43   511830097920  2.756900e+10
# 7            Oil & Gas Integrated        109.61   467013140480  7.302500e+10
# 8      Drug Manufacturers—General        170.43   448674004992  3.238200e+10
# 9                 Discount Stores        140.75   390423609344  3.502800e+10
#
#    Revenuegrowth           City State        Country  Fulltimeemployees  \
# 0          0.081      Cupertino    CA  United States           164000.0
# 1          0.124        Redmond    WA  United States           221000.0
# 2          0.061  Mountain View    CA  United States           186779.0
# 3          0.061  Mountain View    CA  United States           186779.0
# 4          0.147        Seattle    WA  United States          1544000.0
# 5          0.102          Omaha    NE  United States           372000.0
# 6          0.126     Minnetonka    MN  United States           350000.0
# 7          0.745         Irving    TX  United States            63000.0
# 8          0.030  New Brunswick    NJ  United States           141700.0
# 9          0.024    Bentonville    AR  United States          2300000.0
#
#                                  Longbusinesssummary    Weight
# 0  Apple Inc. designs, manufactures, and markets ...  0.069090
# 1  Microsoft Corporation develops, licenses, and ...  0.049486
# 2  Alphabet Inc. provides various products and pl...  0.033734
# 3  Alphabet Inc. provides various products and pl...  0.033719
# 4  Amazon.com, Inc. engages in the retail sale of...  0.028143
# 5  Berkshire Hathaway Inc., through its subsidiar...  0.019121
# 6  UnitedHealth Group Incorporated operates as a ...  0.015327
# 7  Exxon Mobil Corporation explores for and produ...  0.013985
# 8  Johnson & Johnson, together with its subsidiar...  0.013436
# 9  Walmart Inc. engages in the operation of retai...  0.011692

# %%
snp_comps.tail(10)
# Out:
#     Exchange Symbol                 Shortname                  Longname  \
# 485      NYQ    PNR              Pentair plc.               Pentair plc
# 486      NYQ   GNRC    Generac Holdlings Inc.     Generac Holdings Inc.
# 487      NYQ     RL  Ralph Lauren Corporation  Ralph Lauren Corporation
# 488      NYQ    OGN             Organon & Co.             Organon & Co.
# 489      NYQ    SEE    Sealed Air Corporation    Sealed Air Corporation
# 490      NMS   XRAY      DENTSPLY SIRONA Inc.      DENTSPLY SIRONA Inc.
# 491      NYQ    MHK   Mohawk Industries, Inc.   Mohawk Industries, Inc.
# 492      NYQ    ALK    Alaska Air Group, Inc.    Alaska Air Group, Inc.
# 493      NMS    NWL        Newell Brands Inc.        Newell Brands Inc.
# 494      NYQ    VNO      Vornado Realty Trust      Vornado Realty Trust
#
#                  Sector                            Industry  Currentprice  \
# 485         Industrials      Specialty Industrial Machinery         40.39
# 486         Industrials      Specialty Industrial Machinery        105.71
# 487   Consumer Cyclical               Apparel Manufacturing         90.30
# 488          Healthcare          Drug Manufacturers—General         25.93
# 489   Consumer Cyclical              Packaging & Containers         42.42
# 490          Healthcare      Medical Instruments & Supplies         28.18
# 491   Consumer Cyclical  Furnishings, Fixtures & Appliances         90.47
# 492         Industrials                            Airlines         43.56
# 493  Consumer Defensive       Household & Personal Products         12.86
# 494         Real Estate                         REIT—Office         22.84
#
#       Marketcap        Ebitda  Revenuegrowth         City State  \
# 485  6683656192  7.464000e+08          0.131       London   NaN
# 486  6669243904  8.144750e+08          0.407     Waukesha    WI
# 487  6647615488  1.055800e+09          0.183     New York    NY
# 488  6574551552  2.100000e+09          0.041  Jersey City    NJ
# 489  6284819456  1.120500e+09          0.119    Charlotte    NC
# 490  6160345600  9.170000e+08         -0.060    Charlotte    NC
# 491  6127750144  1.888004e+09          0.067      Calhoun    GA
# 492  5524889088  1.073000e+09          0.448      Seattle    WA
# 493  5470643712  1.390000e+09         -0.065      Atlanta    GA
# 494  4377993728  8.103430e+08          0.163     New York    NY
#
#             Country  Fulltimeemployees  \
# 485  United Kingdom            11250.0
# 486   United States             8955.0
# 487   United States            13500.0
# 488   United States             9300.0
# 489   United States            16500.0
# 490   United States            15000.0
# 491   United States            43000.0
# 492   United States            22354.0
# 493   United States            32000.0
# 494   United States             3224.0
#
#                                    Longbusinesssummary    Weight
# 485  Pentair plc provides various water solutions w...  0.000200
# 486  Generac Holdings Inc. designs, manufactures, a...  0.000200
# 487  Ralph Lauren Corporation designs, markets, and...  0.000199
# 488  Organon & Co., a health care company, develops...  0.000197
# 489  Sealed Air Corporation provides food safety an...  0.000188
# 490  DENTSPLY SIRONA Inc. manufactures and sells va...  0.000184
# 491  Mohawk Industries, Inc. designs, manufactures,...  0.000184
# 492  Alaska Air Group, Inc., through its subsidiari...  0.000165
# 493  Newell Brands Inc. designs, manufactures, sour...  0.000164
# 494  Vornado's portfolio is concentrated in the nat...  0.000131

# %%
snp_comps.columns
# Out:
# Index(['Exchange', 'Symbol', 'Shortname', 'Longname', 'Sector', 'Industry',
#        'Currentprice', 'Marketcap', 'Ebitda', 'Revenuegrowth', 'City', 'State',
#        'Country', 'Fulltimeemployees', 'Longbusinesssummary', 'Weight'],
#       dtype='object')

# %%
snp_comps.index
# Out:
# RangeIndex(start=0, stop=495, step=1)

# %%
# (행 개수, 열 개수)
snp_comps.shape
# Out:
# (495, 16)

# %%
len(snp_comps)
# Out:
# 495

# %% [markdown]
# ## 인덱싱(indexing) & 슬라이싱(slicing)
# - 인덱스를 설정해보고,
# - 원하는 조건의 데이터를 추출해보기

# %% [markdown]
# ### 기본 인덱스는 RangeIndex!

# %%
# 0 부터 행 개수까지 번호
snp_comps.index
# Out:
# RangeIndex(start=0, stop=495, step=1)

# %%
snp_comps
# Out:
#     Exchange Symbol                Shortname                 Longname  \
# 0        NMS   AAPL               Apple Inc.               Apple Inc.
# 1        NMS   MSFT    Microsoft Corporation    Microsoft Corporation
# 2        NMS  GOOGL            Alphabet Inc.            Alphabet Inc.
# 3        NMS   GOOG            Alphabet Inc.            Alphabet Inc.
# 4        NMS   AMZN         Amazon.com, Inc.         Amazon.com, Inc.
# ..       ...    ...                      ...                      ...
# 490      NMS   XRAY     DENTSPLY SIRONA Inc.     DENTSPLY SIRONA Inc.
# 491      NYQ    MHK  Mohawk Industries, Inc.  Mohawk Industries, Inc.
# 492      NYQ    ALK   Alaska Air Group, Inc.   Alaska Air Group, Inc.
# 493      NMS    NWL       Newell Brands Inc.       Newell Brands Inc.
# 494      NYQ    VNO     Vornado Realty Trust     Vornado Realty Trust
#
#                      Sector                            Industry  Currentprice  \
# 0                Technology                Consumer Electronics        145.03
# 1                Technology             Software—Infrastructure        220.10
# 2    Communication Services      Internet Content & Information         86.97
# 3    Communication Services      Internet Content & Information         87.07
# 4         Consumer Cyclical                     Internet Retail         92.12
# ..                      ...                                 ...           ...
# 490              Healthcare      Medical Instruments & Supplies         28.18
# 491       Consumer Cyclical  Furnishings, Fixtures & Appliances         90.47
# 492             Industrials                            Airlines         43.56
# 493      Consumer Defensive       Household & Personal Products         12.86
# 494             Real Estate                         REIT—Office         22.84
#
#          Marketcap        Ebitda  Revenuegrowth           City State  \
# 0    2307151626240  1.305410e+11          0.081      Cupertino    CA
# 1    1652506361856  9.798300e+10          0.124        Redmond    WA
# 2    1126496337920  9.373300e+10          0.061  Mountain View    CA
# 3    1125998002176  9.373300e+10          0.061  Mountain View    CA
# 4     939780669440  5.154900e+10          0.147        Seattle    WA
# ..             ...           ...            ...            ...   ...
# 490     6160345600  9.170000e+08         -0.060      Charlotte    NC
# 491     6127750144  1.888004e+09          0.067        Calhoun    GA
# 492     5524889088  1.073000e+09          0.448        Seattle    WA
# 493     5470643712  1.390000e+09         -0.065        Atlanta    GA
# 494     4377993728  8.103430e+08          0.163       New York    NY
#
#            Country  Fulltimeemployees  \
# 0    United States           164000.0
# 1    United States           221000.0
# 2    United States           186779.0
# 3    United States           186779.0
# 4    United States          1544000.0
# ..             ...                ...
# 490  United States            15000.0
# 491  United States            43000.0
# 492  United States            22354.0
# 493  United States            32000.0
# 494  United States             3224.0
#
#                                    Longbusinesssummary    Weight
# 0    Apple Inc. designs, manufactures, and markets ...  0.069090
# 1    Microsoft Corporation develops, licenses, and ...  0.049486
# 2    Alphabet Inc. provides various products and pl...  0.033734
# 3    Alphabet Inc. provides various products and pl...  0.033719
# 4    Amazon.com, Inc. engages in the retail sale of...  0.028143
# ..                                                 ...       ...
# 490  DENTSPLY SIRONA Inc. manufactures and sells va...  0.000184
# 491  Mohawk Industries, Inc. designs, manufactures,...  0.000184
# 492  Alaska Air Group, Inc., through its subsidiari...  0.000165
# 493  Newell Brands Inc. designs, manufactures, sour...  0.000164
# 494  Vornado's portfolio is concentrated in the nat...  0.000131
#
# [495 rows x 16 columns]

# %% [markdown]
# ### 새로운 인덱스 설정하기
# - set_index : 인덱스 설정
# - reset_index : 인덱스 재설정
# - options : inplace=True
# - Multiindex 멀티 인덱스

# %%
snp_comps = snp_comps.set_index('Symbol')

# %% [markdown]
# ### 특정 행 또는 열 추출
# - indexing & slicing
#
#
# - 행 추출
#     - df.loc[행]
#     - df.loc[행, :]
#
#
# - 열 추출
#     - df[열] / df.열
#     - df.loc[:, 열]
#
#
# - element 추출
#     - df.loc[행, 열]
#
#
# - bool 타입으로 추출
#     - df.loc[list of bool, :]
#
#
# - iloc (integer location) 추출
#     - df.iloc[행번호, 열번호]
#
#
# - filter 사용
#     - df.filter(regex='A', axis=0)

# %%
snp_comps.filter(regex='name', axis=1)
# Out:
#                       Shortname                 Longname
# Symbol
# AAPL                 Apple Inc.               Apple Inc.
# MSFT      Microsoft Corporation    Microsoft Corporation
# GOOGL             Alphabet Inc.            Alphabet Inc.
# GOOG              Alphabet Inc.            Alphabet Inc.
# AMZN           Amazon.com, Inc.         Amazon.com, Inc.
# ...                         ...                      ...
# XRAY       DENTSPLY SIRONA Inc.     DENTSPLY SIRONA Inc.
# MHK     Mohawk Industries, Inc.  Mohawk Industries, Inc.
# ALK      Alaska Air Group, Inc.   Alaska Air Group, Inc.
# NWL          Newell Brands Inc.       Newell Brands Inc.
# VNO        Vornado Realty Trust     Vornado Realty Trust
#
# [495 rows x 2 columns]

# %%
snp_comps.filter(regex='A$', axis=0)
# Out:
#        Exchange                        Shortname  \
# Symbol
# NVDA        NMS               NVIDIA Corporation
# MA          NYQ          Mastercard Incorporated
# TSLA        NMS                      Tesla, Inc.
# CMCSA       NMS              Comcast Corporation
# BA          NYQ             Boeing Company (The)
# HCA         NYQ             HCA Healthcare, Inc.
# MRNA        NMS                    Moderna, Inc.
# PSA         NYQ                   Public Storage
# CTVA        NYQ                    Corteva, Inc.
# A           NYQ       Agilent Technologies, Inc.
# EA          NMS             Electronic Arts Inc.
# WBA         NMS   Walgreens Boots Alliance, Inc.
# CTRA        NYQ              Coterra Energy Inc.
# ULTA        NMS                Ulta Beauty, Inc.
# MAA         NYQ  Mid-America Apartment Communiti
# FOXA        NMS                  Fox Corporation
# APA         NMS                  APA Corporation
# ZBRA        NMS   Zebra Technologies Corporation
# SNA         NYQ             Snap-On Incorporated
# NWSA        NMS                 News Corporation
# CMA         NYQ            Comerica Incorporated
# BWA         NYQ                  BorgWarner Inc.
# DVA         NYQ                      DaVita Inc.
#
#                                        Longname                  Sector  \
# Symbol
# NVDA                         NVIDIA Corporation              Technology
# MA                      Mastercard Incorporated      Financial Services
# TSLA                                Tesla, Inc.       Consumer Cyclical
# CMCSA                       Comcast Corporation  Communication Services
# BA                           The Boeing Company             Industrials
# HCA                        HCA Healthcare, Inc.              Healthcare
# MRNA                              Moderna, Inc.              Healthcare
# PSA                              Public Storage             Real Estate
# CTVA                              Corteva, Inc.         Basic Materials
# A                    Agilent Technologies, Inc.              Healthcare
# EA                         Electronic Arts Inc.  Communication Services
# WBA              Walgreens Boots Alliance, Inc.              Healthcare
# CTRA                        Coterra Energy Inc.                  Energy
# ULTA                          Ulta Beauty, Inc.       Consumer Cyclical
# MAA     Mid-America Apartment Communities, Inc.             Real Estate
# FOXA                            Fox Corporation  Communication Services
# APA                             APA Corporation                  Energy
# ZBRA             Zebra Technologies Corporation              Technology
# SNA                        Snap-on Incorporated             Industrials
# NWSA                           News Corporation  Communication Services
# CMA                       Comerica Incorporated      Financial Services
# BWA                             BorgWarner Inc.       Consumer Cyclical
# DVA                                 DaVita Inc.              Healthcare
#
#                               Industry  Currentprice     Marketcap  \
# Symbol
# NVDA                    Semiconductors        132.19  329417490432
# MA                     Credit Services        319.82  314241384448
# TSLA                Auto Manufacturers        214.98  215895801856
# CMCSA                 Telecom Services         30.91  141225312256
# BA                 Aerospace & Defense        147.41   87853850624
# HCA            Medical Care Facilities        213.82   66502942720
# MRNA                     Biotechnology        148.62   60257976320
# PSA                    REIT—Industrial        283.02   49628971008
# CTVA               Agricultural Inputs         66.91   48771301376
# A               Diagnostics & Research        135.27   40045465600
# EA      Electronic Gaming & Multimedia        128.66   36386078720
# WBA           Pharmaceutical Retailers         35.81   30937872384
# CTRA                     Oil & Gas E&P         30.68   24960573440
# ULTA                  Specialty Retail        406.77   22014472192
# MAA                   REIT—Residential        153.21   17640294400
# FOXA                     Entertainment         30.05   16555867136
# APA                      Oil & Gas E&P         44.24   14445686784
# ZBRA           Communication Equipment        236.03   12613796864
# SNA                Tools & Accessories        220.03   11779306496
# NWSA                     Entertainment         16.47    9783591936
# CMA                     Banks—Regional         67.79    8890591232
# BWA                         Auto Parts         36.34    8509156352
# DVA            Medical Care Facilities         69.76    7108544000
#
#               Ebitda  Revenuegrowth          City State        Country  \
# Symbol
# NVDA    1.253300e+10          0.464   Santa Clara    CA  United States
# MA      1.258900e+10          0.214      Purchase    NY  United States
# TSLA    1.403000e+10          0.416        Austin    TX  United States
# CMCSA   3.628300e+10          0.051  Philadelphia    PA  United States
# BA     -2.681000e+09          0.044       Chicago    IL  United States
# HCA     1.227000e+10          0.027     Nashville    TN  United States
# MRNA    1.655300e+10          2.132     Cambridge    MA  United States
# PSA     2.647535e+09          0.263      Glendale    CA  United States
# CTVA    3.765000e+09          0.101  Indianapolis    IN  United States
# A       1.922000e+09          0.083   Santa Clara    CA  United States
# EA      1.634000e+09          0.356  Redwood City    CA  United States
# WBA     4.610000e+09         -0.042     Deerfield    IL  United States
# CTRA    3.284000e+09          3.243       Houston    TX  United States
# ULTA    1.685629e+09          0.210   Bolingbrook    IL  United States
# MAA     1.077237e+09          0.133    Germantown    TN  United States
# FOXA    2.902000e+09          0.075      New York    NY  United States
# APA     7.057000e+09          0.627       Houston    TX  United States
# ZBRA    1.149000e+09          0.063  Lincolnshire    IL  United States
# SNA     1.296800e+09          0.047       Kenosha    WI  United States
# NWSA    1.328000e+09          0.067      New York    NY  United States
# CMA              NaN         -0.074        Dallas    TX  United States
# BWA     2.101000e+09          0.189  Auburn Hills    MI  United States
# DVA     2.355009e+09         -0.001        Denver    CO  United States
#
#         Fulltimeemployees                                Longbusinesssummary  \
# Symbol
# NVDA              22473.0  NVIDIA Corporation provides graphics, and comp...
# MA                24000.0  Mastercard Incorporated, a technology company,...
# TSLA              99290.0  Tesla, Inc. designs, develops, manufactures, l...
# CMCSA            189000.0  Comcast Corporation operates as a media and te...
# BA               142000.0  The Boeing Company, together with its subsidia...
# HCA              204000.0  HCA Healthcare, Inc., through its subsidiaries...
# MRNA               3200.0  Moderna, Inc., a biotechnology company, discov...
# PSA                5800.0  Public Storage, a member of the S&P 500 and FT...
# CTVA              21000.0  Corteva, Inc. operates in the agriculture busi...
# A                 17700.0  Agilent Technologies, Inc. provides applicatio...
# EA                12900.0  Electronic Arts Inc. develops, markets, publis...
# WBA              315000.0  Walgreens Boots Alliance, Inc. operates as a p...
# CTRA                936.0  Coterra Energy Inc., an independent oil and ga...
# ULTA              16500.0  Ulta Beauty, Inc. operates as a retailer of be...
# MAA                2429.0  MAA, an S&P 500 company, is a real estate inve...
# FOXA               9000.0  Fox Corporation operates as a news, sports, an...
# APA                2253.0  APA Corporation, through its subsidiaries, exp...
# ZBRA               9800.0  Zebra Technologies Corporation, together with ...
# SNA               12800.0  Snap-on Incorporated manufactures and markets ...
# NWSA              24000.0  News Corporation, a media and information serv...
# CMA                7436.0  Comerica Incorporated, through its subsidiarie...
# BWA               49300.0  BorgWarner Inc. provides solutions for combust...
# DVA               69000.0  DaVita Inc. provides kidney dialysis services ...
#
#           Weight
# Symbol
# NVDA    0.009865
# MA      0.009410
# TSLA    0.006465
# CMCSA   0.004229
# BA      0.002631
# HCA     0.001991
# MRNA    0.001804
# PSA     0.001486
# CTVA    0.001461
# A       0.001199
# EA      0.001090
# WBA     0.000926
# CTRA    0.000747
# ULTA    0.000659
# MAA     0.000528
# FOXA    0.000496
# APA     0.000433
# ZBRA    0.000378
# SNA     0.000353
# NWSA    0.000293
# CMA     0.000266
# BWA     0.000255
# DVA     0.000213

# %% [markdown]
# ## 정렬(sorting)
# - df.sort_index()
# - df.sort_values()
# - options : ascending=True/False

# %%
snp_comps.sort_index(ascending=True)

# %%
snp_comps.sort_values('Weight', ascending=False)

# %% [markdown]
# ## 행/열 이름 변경(rename)
# - df.rename(dicts, axis=0)
# - df.rename(columns=dicts)

# %%
snp_comps.rename({'AAPL' : 'AAPL US Equity'}, axis=0)
# Out:
#     Exchange Symbol                Shortname                 Longname  \
# 0        NMS   AAPL               Apple Inc.               Apple Inc.
# 1        NMS   MSFT    Microsoft Corporation    Microsoft Corporation
# 2        NMS  GOOGL            Alphabet Inc.            Alphabet Inc.
# 3        NMS   GOOG            Alphabet Inc.            Alphabet Inc.
# 4        NMS   AMZN         Amazon.com, Inc.         Amazon.com, Inc.
# ..       ...    ...                      ...                      ...
# 490      NMS   XRAY     DENTSPLY SIRONA Inc.     DENTSPLY SIRONA Inc.
# 491      NYQ    MHK  Mohawk Industries, Inc.  Mohawk Industries, Inc.
# 492      NYQ    ALK   Alaska Air Group, Inc.   Alaska Air Group, Inc.
# 493      NMS    NWL       Newell Brands Inc.       Newell Brands Inc.
# 494      NYQ    VNO     Vornado Realty Trust     Vornado Realty Trust
#
#                      Sector                            Industry  Currentprice  \
# 0                Technology                Consumer Electronics        145.03
# 1                Technology             Software—Infrastructure        220.10
# 2    Communication Services      Internet Content & Information         86.97
# 3    Communication Services      Internet Content & Information         87.07
# 4         Consumer Cyclical                     Internet Retail         92.12
# ..                      ...                                 ...           ...
# 490              Healthcare      Medical Instruments & Supplies         28.18
# 491       Consumer Cyclical  Furnishings, Fixtures & Appliances         90.47
# 492             Industrials                            Airlines         43.56
# 493      Consumer Defensive       Household & Personal Products         12.86
# 494             Real Estate                         REIT—Office         22.84
#
#          Marketcap        Ebitda  Revenuegrowth           City State  \
# 0    2307151626240  1.305410e+11          0.081      Cupertino    CA
# 1    1652506361856  9.798300e+10          0.124        Redmond    WA
# 2    1126496337920  9.373300e+10          0.061  Mountain View    CA
# 3    1125998002176  9.373300e+10          0.061  Mountain View    CA
# 4     939780669440  5.154900e+10          0.147        Seattle    WA
# ..             ...           ...            ...            ...   ...
# 490     6160345600  9.170000e+08         -0.060      Charlotte    NC
# 491     6127750144  1.888004e+09          0.067        Calhoun    GA
# 492     5524889088  1.073000e+09          0.448        Seattle    WA
# 493     5470643712  1.390000e+09         -0.065        Atlanta    GA
# 494     4377993728  8.103430e+08          0.163       New York    NY
#
#            Country  Fulltimeemployees  \
# 0    United States           164000.0
# 1    United States           221000.0
# 2    United States           186779.0
# 3    United States           186779.0
# 4    United States          1544000.0
# ..             ...                ...
# 490  United States            15000.0
# 491  United States            43000.0
# 492  United States            22354.0
# 493  United States            32000.0
# 494  United States             3224.0
#
#                                    Longbusinesssummary    Weight
# 0    Apple Inc. designs, manufactures, and markets ...  0.069090
# 1    Microsoft Corporation develops, licenses, and ...  0.049486
# 2    Alphabet Inc. provides various products and pl...  0.033734
# 3    Alphabet Inc. provides various products and pl...  0.033719
# 4    Amazon.com, Inc. engages in the retail sale of...  0.028143
# ..                                                 ...       ...
# 490  DENTSPLY SIRONA Inc. manufactures and sells va...  0.000184
# 491  Mohawk Industries, Inc. designs, manufactures,...  0.000184
# 492  Alaska Air Group, Inc., through its subsidiari...  0.000165
# 493  Newell Brands Inc. designs, manufactures, sour...  0.000164
# 494  Vornado's portfolio is concentrated in the nat...  0.000131
#
# [495 rows x 16 columns]

# %%
snp_comps.rename(columns={'Currentprice' : 'price'})
# snp_comps.rename({'Currentprice' : 'price'}, axis=1)

# %% [markdown]
# ## 복사(copy)
# - df.copy()
# - (!) Mutable / Immutable 개념 이해하기 (list vs. tuple)
# - 데이터프레임(Mutable 객체) 가공 시 주의점

# %%
# mutable vs. immutable : immutable 객체는 생성 이후 변경이 불가능. mutable 객체는 변경 가능한 객체
# 대표적인 mutable 객체는 list / immutable 객체는 tuple
list1 = [1,2,3] # mutable
tuple1 = (1,2,3) # immutable

# %%
#list1[0] = 0 # works
#tuple1[0] = 0 # error

# %%
# pd.DataFrame은 mutable 객체임. 따라서 기존 객체를 새로운 객체로 assign(=) 했을 경우,
# 동일한 데이터를 나타내는 두 개의 이름(변수)가 생기는 것
new_snp_cmp1 = snp_comps

# %%
# 두 객체의 id (메모리상 저장된 주소의 개념)는 동일
# 만약 new_snp_cmp1의 데이터를 변경하면, snp_comps도 변경됨 
id(new_snp_cmp1) == id(snp_comps)

# %%
# 따라서 기존 데이터를 복사(copy)하고자 할 때는, .copy() 메소드를 통해 새로운 메모리 공간에 데이터를 생성하여야 함
new_snp_cmp2 = snp_comps.copy()
id(new_snp_cmp2) == id(snp_comps)

# %% [markdown]
# ## Exercise 1
# - 1) snp_comps에서 AMZN의 섹터(Sector)를 출력
#
# - 2) snp_price 데이터프레임의 인덱스를 'Date'로 설정하고, 2022년 1월 1일 이후 데이터를 출력
#
# - 3) snp_comps에서 섹터(Sector)가 'Technology'인 종목 추출
#
# - 4) snp_comps에서 벤치마크 비중(Weight)이 높은 순으로 정렬
#
# - 5) snp_price에서 S&P500 컬럼 이름을 'Price'로 변경
#
# - 6) snp_stocks의 인덱스를 Date와 Symbol로 설정하고, 2022년 1월 1일 이후 AAPL의 수정주가를 출력 <br>
#     (Hint) Date 컬럼을 먼저 정렬한 후 인덱스 설정해야 함. pd.IndexSlice를 이용하여 multiindex 인덱싱 가능

# %% [markdown]
# ### 1) snp_comps에서 AMZN의 섹터(Sector)를 출력

# %%
snp_comps.loc['AMZN', 'Sector']

# %% [markdown]
# ### 2) snp_price 데이터프레임의 인덱스를 'Date'로 설정하고, 2022년 1월 1일 이후 데이터를 출력

# %%
snp_price.set_index('Date').loc['2022-01-01':]

# %% [markdown]
# ### 3) snp_comps에서 섹터(Sector)가 'Technology'인 종목 추출

# %%
snp_comps.loc[snp_comps.Sector == 'Technology']

# %% [markdown]
# ### 4) snp_comps에서 벤치마크 비중(Weight)이 높은 순으로 정렬

# %%
snp_comps.sort_values('Weight', ascending=False)

# %% [markdown]
# ### 5) snp_price에서 S&P500 컬럼 이름을 'Price'로 변경

# %%
snp_price.rename(columns={'S&P500' : 'Price'})

# %% [markdown]
# ### snp_stocks의 인덱스를 Date와 Symbol로 설정하고, 2022년 1월 1일 이후 AAPL의 수정주가를 출력
#     (Hint) Date 컬럼을 먼저 정렬한 후 인덱스 설정해야 함. pd.IndexSlice를 이용하여 multiindex 인덱싱 가능

# %%
snp_stocks = snp_stocks.sort_values('Date')

# %%
snp_stocks = snp_stocks.set_index(['Date', 'Symbol'])

# %%
snp_stocks.loc[pd.IndexSlice['2022-01-01':, 'AAPL'], 'Adj Close']
# Out:
# Date        Symbol
# 2022-01-03  AAPL      182.009995
# 2022-01-04  AAPL      179.699997
# 2022-01-05  AAPL      174.919998
# 2022-01-06  AAPL      172.000000
# 2022-01-07  AAPL      172.169998
#                          ...
# 2022-10-27  AAPL      144.800003
# 2022-10-28  AAPL      155.740005
# 2022-10-31  AAPL      153.339996
# 2022-11-01  AAPL      150.649994
# 2022-11-02  AAPL      145.029999
# Name: Adj Close, Length: 211, dtype: float64
